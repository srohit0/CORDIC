# %% [markdown]
# <a href="https://colab.research.google.com/github/srohit0/CORDIC/blob/master/food_mnist_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Using food_mnist dataset

# %%
# %%time
! git clone https://github.com/srohit0/food_mnist.git
  
import food_mnist

(x_train, y_train), (x_test, y_test) = food_mnist.load_data()
labels_dict = food_mnist.labels()

# %%
print(y_train[0])

# %% [markdown]
# ## Display Images

# %%
import random
from google.colab.patches import cv2_imshow

print("Image shape:", x_train[0].shape)
for x in range(4):
  image = x_train[random.randint(0,3750)]
  cv2_imshow(image)
